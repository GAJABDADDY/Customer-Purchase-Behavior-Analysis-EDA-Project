# %% [markdown]
# <a href="https://colab.research.google.com/github/GAJABDADDY/Customer-Purchase-Behavior-Analysis-EDA-Project/blob/main/Ashish's_Applied_Statistics_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %% [markdown]
# ###Import Libraries:

# %%
#Importing NumPy library
import numpy as np

#Importing Pandas library
import pandas as pd

#Importing Matplotlib and Seaborn library
import seaborn as sns
import matplotlib.pyplot as plt

#Importing Google Drive Package from google.colab library
from google.colab import drive
drive.mount('/content/drive') #mounting google drive

#We'll import the rest of the libraries later on..
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Load Dataset:

# %%
# Load Dataset

filepath="/content/drive/MyDrive/Applied Statistics Assignment/Superstore Marketing Data - Sheet1.csv"
df=pd.read_csv(filepath)

# %% [markdown]
# ###Dataset First View:

# %%
# Dataset First Look

df.head() #Shows the first 5 rows of the dataset by default
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
df.tail() #Shows the last 5 rows of the dataset by default
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    ########       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0    ########       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    ########       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %% [markdown]
# ###Dataset Information:

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# From the following dataset information, we can deduce that all the columns have 2240 rows except for the column 'Income' which has 2216 non-null rows indicating 24 null rows. As the rest of the columns have consistent data, therefore, we'll just replace the empty rows with 'na'.
#
# Below, we have shown a heatmap visualisation showing the amount of missing values in the dataset.

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df.fillna('na')
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# Here, the .fillna() method converts all the null values to the specified parameter. This in turn ensures the data is more user-friendly and in a better readable format.

# %% [markdown]
# We can also there are some rows with '########' as the value in the 'Dt_Customer' column. Let's see..

# %%
count=0
for i in df['Dt_Customer']:
  if i=='########':
    count+=1
  else:
    pass
print(count)
# Out:
# 916

# %% [markdown]
# As we can see there are 916 rows with missing date values, we will need to first convert the 'Dt_Customer' column to datetime datatype to fill in those missing values with an imputation method.

# %% [markdown]
# To first convert to datetime, we need to take care of '########' values present in the 'Dt_Customer' column.

# %%
df['Dt_Customer'] = df['Dt_Customer'].replace('########', pd.NaT) #NaT stands for  'Not a Time' in pandas

# %%
df['Dt_Customer'].head
# Out:
# <bound method NDFrame.head of 0        6/16/2014
# 1        6/15/2014
# 2        5/13/2014
# 3              NaT
# 4              NaT
#            ...
# 2235           NaT
# 2236     1/22/2013
# 2237           NaT
# 2238    11/29/2012
# 2239           NaT
# Name: Dt_Customer, Length: 2240, dtype: object>

# %% [markdown]
# We can see the # values have been replaced with NaT values. Now, we can proceed to change the datatype to datetime.

# %%
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'], errors='coerce') #any errors will be converted to NaT values

# %% [markdown]
# Now, we'll check if there are any remaing invalid values:

# %%
# Check for remaining invalid values

invalid_values = df[df['Dt_Customer'].isnull()]['Dt_Customer']
print("Invalid values after conversion:", invalid_values)
# Out:
# Invalid values after conversion: 3      NaT
# 4      NaT
# 8      NaT
# 9      NaT
# 11     NaT
#         ..
# 2231   NaT
# 2232   NaT
# 2235   NaT
# 2237   NaT
# 2239   NaT
# Name: Dt_Customer, Length: 916, dtype: datetime64[ns]

# %% [markdown]
# We found 3 invalid values after conversion but as they have been also to converted to 'NaT ' values with the help of 'Coerce' parameter, we'll continue with applying the imputation method.

# %% [markdown]
# **Imputation Methods:**
#
# Imputation methods are techniques used to fill in missing values in a dataset with estimated values. These methods are particularly useful when dealing with incomplete datasets, as missing data can adversely affect the performance of machine learning models and statistical analyses.
#
# We are going to use the linear interpolation method here to assume missing values for the dates.
#
# **Linear Interpolation:**
#
# Forward Fill (or Backward Fill):
#
# Method: Fill missing dates with the last observed date (forward fill) along the same column.

# %%
# Perform linear interpolation to fill missing dates using forward fill
df['Dt_Customer'] = df['Dt_Customer'].interpolate(method='pad')  # or method='ffill'

# %% [markdown]
# As you can see, we have performed the ff (Forward Fill) interpolation imputation method and filled the missing dates in the column 'Dt_Customer'.

# %% [markdown]
# Checking the remaining no. of NaN values:

# %%
nan_count = df['Dt_Customer'].isna().sum()
print(nan_count)
# Out:
# 0

# %%
df['Dt_Customer']
# Out:
# 0      2014-06-16
# 1      2014-06-15
# 2      2014-05-13
# 3      2014-05-13
# 4      2014-05-13
#           ...
# 2235   2013-09-17
# 2236   2013-01-22
# 2237   2013-01-22
# 2238   2012-11-29
# 2239   2012-11-29
# Name: Dt_Customer, Length: 2240, dtype: datetime64[ns]

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# Although we have cleared all the missing values for the column 'Dt_Customer', we still have some missing values for the column 'Income'.
#
# First, let's check the no. of missing values in the column 'Income'.

# %%
nan_count = df['Income'].isna().sum()
print(nan_count)
# Out:
# 24

# %% [markdown]
# As there are only 24 missing values, we'll use a simple imputation method called the 'Median Imputation' as they'll replace missing income values with the mean of the existing income values. As the median value can be skewed if there is any outlier, let's first check if there is any..

# %%
df['Income'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# We can see a single value greater than 600000 while the rest lie between 100000-200000.. Hence, we will ignore that value by creating a threshhold so that the median value is not skewed.

# %%
# Identify and handle outliers (e.g., values above 3 standard deviations from the mean)
#mean_income = df['Income'].mean()
income_outlier = 600000

# Exclude outliers from the income data
income_no_outliers = df['Income'][df['Income'] <= income_outlier]

# Calculate median excluding outliers
median_income_no_outliers = np.median(income_no_outliers)

# Fill missing income values with adjusted median (excluding outliers)
df['Income'].fillna(median_income_no_outliers, inplace=True)

# %% [markdown]
# We have successfully filled the missing values with the median value of the column 'Income'.
#
# Now, let's check if there are any missing values or not..

# %%
nan_count = df['Income'].isna().sum()
print(nan_count)
# Out:
# 0

# %% [markdown]
# As there are no missing values, let's check through the box plot chart once again to see if there was any outlier value created while calculating the median..

# %%
df['Income'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# As we can see, there hasn't been any outlier value created..

# %% [markdown]
# Finally, we'll delete the row with an outlier value in the column 'Income' as it will skew the measures of central tendency by a lot.

# %%
# Drop rows with 'Income' greater than 600000
df = df[df['Income'] <= 600000]

total_rows = len(df['Income'])
print(total_rows)
# Out:
# 2239

# %%
print(df['Income'].max()) #Showing the current max value of the column 'Income'.
# Out:
# 162397.0

# %% [markdown]
# Since the total no. of rows has gone from 2240 to 2239, we can say that the outlier value has been removed and our dataset is now completely free from any ouliers or missing values!!

# %% [markdown]
# Let's check the heatmap once again to see if there are any missing values left.

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# From the above graph, We can see that there are no outliers or any missing values left in the dataset for us to clean. Our Data Cleaning process has been completed.

# %% [markdown]
# ### Summary of Basic Statistics:

# %% [markdown]
# Now, that we have cleaned and organised our dataset, we'll just look at the basic summary of the dataset with the help of just one command.
#
# Note that we will be looking at all these measures in detail in the next section i.e Task 2.

# %%
df.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2239.000000  2239.000000    2239.000000  2239.000000  2239.000000
# mean    5590.444841  1968.802144   51963.463600     0.443948     0.506476
# std     3246.372471    11.985494   21410.674611     0.538390     0.544555
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2827.500000  1959.000000   35533.500000     0.000000     0.000000
# 50%     5455.000000  1970.000000   51373.000000     0.000000     0.000000
# 75%     8423.500000  1977.000000   68277.500000     1.000000     1.000000
# max    11191.000000  1996.000000  162397.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2239.000000  2239.000000  2239.000000      2239.000000
# mean     49.121036   304.067441    26.307727       167.016525
# std      28.963662   336.614830    39.781468       225.743829
# ...

# %% [markdown]
# From the above code, we can see the calculated statistics such as mean, median and standard deviation for each relevant numerical variable.

# %% [markdown]
# The describe() method in pandas is used to generate descriptive statistics of the DataFrame or Series. It provides a summary of the central tendency, dispersion, and shape of the distribution of numerical data.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %% [markdown]
# To determine which descriptive statistics to compute for each column in our dataset, it's important to understand the type of data each column represents and the goal of our analysis.

# %% [markdown]
# We'll first distribute the variables into 3 types:
#
#
#
# 1.   **Categorical Variables:**
#
#       These variables represent categories or groups. They can take on a limited and usually fixed number of possible values that represent different groups or categories. These values are typically labels or names.
#
#
# 2.   **Continuous Variables:**
#
#       Continuous variables are numeric variables that can take on an infinite number of values within a certain range. They can be measured at any point along a continuum.
#
# 3.   **Discrete Variables:**
#
#       Discrete variables are also numeric variables, but they can only take on specific, distinct values. These values are often counted in whole numbers and cannot be broken down into smaller parts.

# %% [markdown]
# ###Categorical Variables:

# %% [markdown]
# **Response**: Since this is binary (1 or 0), we will calculate the proportion of customers who accepted the offer through mean.
#
# **Education**: We'll calculate the mode to find the most common level of education among customers.
#
# **Marital_Status**: Mode to find the most common marital status.

# %%
#Calculating Mean for the column 'Response':

import numpy as np

ans=np.mean(df['Response'])
final_ans=ans*100
print(f'{final_ans:.2f}%')
# Out:
# 14.92%

# %% [markdown]
# This shows that only 14.91% of customers accepted the job in the last campaign.

# %%
#Calculating Mode for the column 'Education':

import statistics

education=statistics.mode(df['Education'])
print(f'The most common level of education among customers is: {education}')
# Out:
# The most common level of education among customers is: Graduation

# %% [markdown]
# This shows the most common level of education among customers is Graduation.

# %%
#Calculating Mode for the column 'Marital':

import statistics

marital=statistics.mode(df['Marital_Status'])
print(f'The most common marital status among customers is: {marital}')
# Out:
# The most common marital status among customers is: Married

# %% [markdown]
# This shows the most common marital status among the customers are Married people.

# %% [markdown]
# ###Continuous Variables:

# %% [markdown]
# **Year_Birth**: Mean, median, variance, and standard deviation to understand the distribution of ages.
#
# **Income**: Mean, median, variance, and standard deviation to understand the distribution of income levels.
#
# **MntFishProducts, MntMeatProducts, MntFruits, MntSweetProducts, MntWines, MntGoldProds**: Mean, median, variance, and standard deviation to understand the average and variability of spending on different product categories.
#
# **NumDealsPurchases, NumCatalogPurchases, NumStorePurchases, NumWebPurchases, NumWebVisitsMonth, Recency**: Mean, median, variance, and standard deviation to understand the average and variability of purchasing behavior and website interactions.

# %%
#Calculating Mean, Median, Variance and Standard Deviation for the column 'Year_Birth':

import numpy as np

mean=np.mean(df['Year_Birth'])
median=np.median(df['Year_Birth'])
variance=np.var(df['Year_Birth'])
std=np.std(df['Year_Birth'])
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}')
# Out:
# The Mean is: 1968.80
# The Median is: 1970.00
# The Variance is: 143.59
# The Standard Deviation is: 11.98

# %% [markdown]
# From the above calculations, we can see that:
#
# The Mean of 1968.81 indicates that, on average, the birth year of customers in your dataset is around 1969 (rounded to the nearest whole year). This is the sum of all the birth years divided by the number of customers.
#
# The median of 1970.0 means that 50% of the customers were born before the year 1970 and 50% were born after. It's the middle value when all birth years are arranged in ascending order. Since it's close to the mean, it suggests that the distribution of birth years is roughly symmetric.
#
# The variance of 143.55 is a measure of how spread out the birth years are from the mean. A higher variance indicates that the birth years are more spread out from the average. Since this value is not extremely high, it suggests that the birth years are somewhat tightly clustered around the mean.
#
# The standard deviation of 11.98 is the square root of the variance. It measures the average amount of variation or dispersion of the birth years from the mean. In this case, a standard deviation of around 12 means that, on average, most birth years are within 12 years of the mean.

# %%
#Calculating Mean, Median, Variance and Standard Deviation for the column 'Income':

import numpy as np

mean=np.mean(df['Income'])
median=np.median(df['Income'])
variance=np.var(df['Income'])
std=np.std(df['Income'])
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}')
# Out:
# The Mean is: 51963.46
# The Median is: 51373.00
# The Variance is: 458212245.47
# The Standard Deviation is: 21405.89

# %% [markdown]
# From the above calculations, we can see that:
#
# The mean of 51963.46 indicates that, on average, the yearly income of customers in our dataset is approximately $51,963.46.
#
# Median:
#
# The median of 51373.00 means that 50% of the customers have an income below $51,373.00, and 50% have an income above this value. The median is less sensitive to extreme values (outliers) compared to the mean.
#
# Variance:
#
# The variance of 458212245.47 measures how much the income values vary from the mean. A higher variance indicates that the incomes are more spread out from the average. In this case, the variance is quite large, suggesting a wide range of income levels in the dataset.
#
# Standard Deviation:
#
# The standard deviation of 21405.89 is the square root of the variance. It measures the average amount of variation or dispersion of the income values from the mean. A standard deviation of approximately $21,405.89 means that most incomes are within this range of the average income.

# %%
#Calculating Mean, Median, Variance and Standard Deviation for the columns 'MntFishProducts', 'MntMeatProducts', 'MntFruits', 'MntSweetProducts', 'MntWines', 'MntGoldProds':

import numpy as np

#Column 'MntFishProducts':
mean=np.mean(df['MntFishProducts'])
median=np.median(df['MntFishProducts'])
variance=np.var(df['MntFishProducts'])
std=np.std(df['MntFishProducts'])
print('For the column MntFishProducts:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')

#Column 'MntMeatProducts':
mean=np.mean(df['MntMeatProducts'])
median=np.median(df['MntMeatProducts'])
variance=np.var(df['MntMeatProducts'])
std=np.std(df['MntMeatProducts'])
print('For the column MntMeatProducts:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')

#Column 'MntFruits':
mean=np.mean(df['MntFruits'])
median=np.median(df['MntFruits'])
variance=np.var(df['MntFruits'])
std=np.std(df['MntFruits'])
print('For the column MntFruits:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')

#Column 'MntSweetProducts':
mean=np.mean(df['MntSweetProducts'])
median=np.median(df['MntSweetProducts'])
variance=np.var(df['MntSweetProducts'])
std=np.std(df['MntSweetProducts'])
print('For the column MntSweetProducts:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')

#Column 'MntWines':
mean=np.mean(df['MntWines'])
median=np.median(df['MntWines'])
variance=np.var(df['MntWines'])
std=np.std(df['MntWines'])
print('For the column MntWines:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')

#Column 'MntGoldProds':
mean=np.mean(df['MntGoldProds'])
median=np.median(df['MntGoldProds'])
variance=np.var(df['MntGoldProds'])
std=np.std(df['MntGoldProds'])
print('For the column MntGoldProds:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')
# Out:
# For the column MntFishProducts:
# The Mean is: 37.54
# The Median is: 12.00
# The Variance is: 2983.94
# The Standard Deviation is: 54.63
#
# For the column MntMeatProducts:
# The Mean is: 167.02
# The Median is: 67.00
# The Variance is: 50937.52
# The Standard Deviation is: 225.69
#
# For the column MntFruits:
# The Mean is: 26.31
# The Median is: 8.00
# The Variance is: 1581.86
# The Standard Deviation is: 39.77
#
# For the column MntSweetProducts:
# The Mean is: 27.07
# The Median is: 8.00
# The Variance is: 1703.78
# The Standard Deviation is: 41.28
#
# For the column MntWines:
# The Mean is: 304.07
# The Median is: 174.00
# The Variance is: 113258.94
# The Standard Deviation is: 336.54
#
# For the column MntGoldProds:
# The Mean is: 44.04
# The Median is: 24.00
# The Variance is: 2720.98
# The Standard Deviation is: 52.16

# %% [markdown]
# **For the 'MntFishProducts' column:**
#
# The mean of 37.53 indicates that, on average, customers spent approximately 37.53 units of currency on fish products in the last 2 years.
#
# The median of 12.00 means that 50% of the customers spent less than 12 units of currency on fish products, and 50% spent more. The median is less sensitive to extreme values (outliers) compared to the mean.
#
# The variance of 2982.99 measures how much the spending on fish products varies from the mean. A higher variance indicates that the spending amounts are more spread out from the average.
#
# The standard deviation of 54.62 is the square root of the variance. It measures the average amount of variation or dispersion of the spending amounts on fish products from the mean. A standard deviation of 54.62 indicates that the spending amounts vary quite a bit from the average.

# %% [markdown]
# **For the 'MntMeatProducts' column:**
#
# The mean of 166.95 indicates that, on average, customers spent approximately 166.95 units of currency on meat products in the last 2 years.
#
# The median of 67.00 means that 50% of the customers spent less than 67 units of currency on meat products, and 50% spent more. The median is less sensitive to extreme values (outliers) compared to the mean.
#
# The variance of 50924.68 measures how much the spending on meat products varies from the mean. A higher variance indicates that the spending amounts are more spread out from the average.
#
# The standard deviation of 225.66 is the square root of the variance. It measures the average amount of variation or dispersion of the spending amounts on meat products from the mean. A standard deviation of 225.66 indicates that the spending amounts vary quite a bit from the average.

# %% [markdown]
# **For the 'MntFruits' column:**
#
# The mean of 26.30 indicates that, on average, customers spent approximately 26.30 units of currency on fruits products in the last 2 years.
#
#
# The median of 8.00 means that 50% of the customers spent less than 8 units of currency on fruits products, and 50% spent more. The median is less sensitive to extreme values (outliers) compared to the mean.
#
#
# The variance of 1581.22 measures how much the spending on fruits products varies from the mean. A higher variance indicates that the spending amounts are more spread out from the average.
#
#
# The standard deviation of 39.76 is the square root of the variance. It measures the average amount of variation or dispersion of the spending amounts on fruits products from the mean. A standard deviation of 39.76 indicates that the spending amounts vary quite a bit from the average.

# %% [markdown]
# **For the 'MntSweetProducts' column:**
#
# The mean of 27.06 indicates that, on average, customers spent approximately 27.06 units of currency on sweet products in the last 2 years.
#
# The median of 8.00 means that 50% of the customers spent less than 8 units of currency on sweet products, and 50% spent more. The median is less sensitive to extreme values (outliers) compared to the mean.
#
# The variance of 1703.32 measures how much the spending on sweet products varies from the mean. A higher variance indicates that the spending amounts are more spread out from the average.
#
# The standard deviation of 41.27 is the square root of the variance. It measures the average amount of variation or dispersion of the spending amounts on sweet products from the mean. A standard deviation of 41.27 indicates that the spending amounts vary quite a bit from the average.

# %% [markdown]
# **For the 'MntWines' column:**
#
# The average amount spent on wine products in the last 2 years is approximately 303.94 units of currency.
#
# The median spending is lower at 173.50 units, suggesting that there are some customers who spend significantly more on wine products, pulling the mean higher.
#
# The variance of 113247.23 and standard deviation of 336.52 indicate that there is a wide range of spending amounts on wine products, with some customers spending considerably more than the average.
#
# Similar to 'MntFishProducts', 'MntMeatProducts', 'MntFruits', and 'MntSweetProducts', the distribution of spending on wine products is likely right-skewed, with a few customers making higher-than-average purchases, resulting in a higher mean compared to the median.

# %% [markdown]
# **For the 'MntGoldProds' column:**
#
# The average amount spent on gold products in the last 2 years is approximately 44.02 units of currency.
#
# The median spending is lower at 24.00 units, suggesting that there are some customers who spend significantly more on gold products, pulling the mean higher.
#
# The variance of 2720.23 and standard deviation of 52.16 indicate that there is a moderate range of spending amounts on gold products, with some customers spending considerably more than the average.
#
# Similar to 'MntFishProducts', 'MntMeatProducts', 'MntFruits', 'MntSweetProducts', and 'MntWines', the distribution of spending on gold products is likely right-skewed, with a few customers making higher-than-average purchases, resulting in a higher mean compared to the median.

# %%
#Calculating Mean, Median, Variance and Standard Deviation for the columns 'NumDealsPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebPurchases', 'NumWebVisitsMonth', 'Recency':

import numpy as np

#Column 'NumDealsPurchases':
mean=np.mean(df['NumDealsPurchases'])
median=np.median(df['NumDealsPurchases'])
variance=np.var(df['NumDealsPurchases'])
std=np.std(df['NumDealsPurchases'])
print('For the column NumDealsPurchases:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')

#Column 'NumCatalogPurchases':
mean=np.mean(df['NumCatalogPurchases'])
median=np.median(df['NumCatalogPurchases'])
variance=np.var(df['NumCatalogPurchases'])
std=np.std(df['NumCatalogPurchases'])
print('For the column NumCatalogPurchases:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')

#Column 'NumStorePurchases':
mean=np.mean(df['NumStorePurchases'])
median=np.median(df['NumStorePurchases'])
variance=np.var(df['NumStorePurchases'])
std=np.std(df['NumStorePurchases'])
print('For the column NumStorePurchases:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')

#Column 'NumWebPurchases':
mean=np.mean(df['NumWebPurchases'])
median=np.median(df['NumWebPurchases'])
variance=np.var(df['NumWebPurchases'])
std=np.std(df['NumWebPurchases'])
print('For the column NumWebPurchases:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')

#Column 'NumWebVisitsMonth':
mean=np.mean(df['NumWebVisitsMonth'])
median=np.median(df['NumWebVisitsMonth'])
variance=np.var(df['NumWebVisitsMonth'])
std=np.std(df['NumWebVisitsMonth'])
print('For the column NumWebVisitsMonth:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')

#Column 'Recency':
mean=np.mean(df['Recency'])
median=np.median(df['Recency'])
variance=np.var(df['Recency'])
std=np.std(df['Recency'])
print('For the column Recency:')
print(f'The Mean is: {mean:.2f}')
print(f'The Median is: {median:.2f}')
print(f'The Variance is: {variance:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')
# Out:
# For the column NumDealsPurchases:
# The Mean is: 2.32
# The Median is: 2.00
# The Variance is: 3.73
# The Standard Deviation is: 1.93
#
# For the column NumCatalogPurchases:
# The Mean is: 2.66
# The Median is: 2.00
# The Variance is: 8.54
# The Standard Deviation is: 2.92
#
# For the column NumStorePurchases:
# The Mean is: 5.79
# The Median is: 5.00
# The Variance is: 10.57
# The Standard Deviation is: 3.25
#
# For the column NumWebPurchases:
# The Mean is: 4.09
# The Median is: 4.00
# The Variance is: 7.72
# The Standard Deviation is: 2.78
#
# For the column NumWebVisitsMonth:
# The Mean is: 5.32
# The Median is: 6.00
# The Variance is: 5.89
# The Standard Deviation is: 2.43
#
# For the column Recency:
# The Mean is: 49.12
# The Median is: 49.00
# The Variance is: 838.52
# The Standard Deviation is: 28.96

# %% [markdown]
# **For the column NumDealsPurchases:**
#
# The average number of purchases made with a discount is approximately 2.33.
#
# The median number of purchases with a discount is 2.00, suggesting that there is a fairly even distribution around this value.
#
# The variance of 3.73 and standard deviation of 1.93 indicate that there is variability in the number of purchases with a discount among customers.
#
# The distribution of the number of purchases with a discount is not heavily skewed, as the mean and median are relatively close. There may be some customers making more purchases with a discount, but the majority are around the average.

# %% [markdown]
# By looking at the mean of these columns, we can see that:
#
#
# 1.   The highest average is for the column 'NumStorePurchase' which shows that people still prefer going to the store to purchase items when compared to doing their purchases online.
#
# 2.   It also shows the average for the column 'NumDealsPurchase' is the lowest indicating that the customers are still not doing high amount of purchases when discount are being offered. This means that the offers are not that great or attractive for them to purchase in bulk..
#
# 3. The mean of online purchases is lower than the mean of online vists indicating that the entirety of online traffic that visits does not translate to purchasing the items.

# %% [markdown]
# **For the 'Recency' column:**
#
# The average number of days since the last purchase is approximately 49.11 days.
#
# The median number of days since the last purchase is 49.00 days, suggesting that there is a fairly even distribution around this value.
#
# The variance of 838.45 and standard deviation of 28.96 indicate that there is variability in the recency of purchases among customers.
#
# The distribution of the recency of purchases is not heavily skewed, as the mean and median are relatively close. There may be some customers who made purchases a long time ago (outliers), but the majority are around the average recency.

# %% [markdown]
# ###Discrete Variables:

# %% [markdown]
# **Kidhome, Teenhome**: Mean and standard deviation to understand the average number of children in different age groups in customer households.
#
#
# **Complain**: Mean to understand the proportion of customers who complained in the last 2 years.

# %%
#Calculating Mean and Standard Deviation for the columns 'Kidhome' and 'Teenhome':

import numpy as np

#Column 'Kidhome':
mean=np.mean(df['Kidhome'])
median=np.median(df['Kidhome'])
variance=np.var(df['Kidhome'])
std=np.std(df['Kidhome'])
print('For the column Kidhome:')
print(f'The Mean is: {mean:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')

#Column 'Teenhome':
mean=np.mean(df['Teenhome'])
median=np.median(df['Teenhome'])
variance=np.var(df['Teenhome'])
std=np.std(df['Teenhome'])
print('For the column Teenhome:')
print(f'The Mean is: {mean:.2f}')
print(f'The Standard Deviation is: {std:.2f}\n')
# Out:
# For the column Kidhome:
# The Mean is: 0.44
# The Standard Deviation is: 0.54
#
# For the column Teenhome:
# The Mean is: 0.51
# The Standard Deviation is: 0.54

# %% [markdown]
# **For the column Kidhome:**
#
# The average number of small children in customers' households is approximately 0.44.
#
# The standard deviation of 0.54 suggests that there is variability in the number of small children among customers. Some customers have more small children, some have fewer, and the distribution is not heavily skewed.
#
# This information can be valuable for understanding the demographics of customers and tailoring marketing or product strategies accordingly. Customers with small children may have different preferences or needs compared to those without, so this data can help in creating targeted campaigns or offers.

# %% [markdown]
# **For the column Teenhome:**
#
# The average number of teenagers in customers' households is approximately 0.51.
#
# The standard deviation of 0.54 suggests that there is variability in the number of teenagers among customers. Some customers have more teenagers, some have fewer, and the distribution is not heavily skewed.

# %%
#Calculating Mean for the column 'Complain':

import numpy as np

ans=np.mean(df['Complain'])
print(f'{ans:.2f}')
# Out:
# 0.01

# %% [markdown]
# This shows that the number of customers who have complained in the last 2 years is less than 1%, which is an excellent result.
#
# This means that the majority of customers (99%) did not file a complaint in the last 2 years. The low mean suggests that complaints are relatively rare occurrences among the customer base.

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
# Probability distributions describe how the probabilities of different outcomes are spread out. In statistics and probability theory, a probability distribution is a mathematical function that provides the probabilities of occurrence of different possible outcomes in an experiment or observation.

# %% [markdown]
# We'll now identify and calculate probability distributions for each column.

# %% [markdown]
# ###**Please Note:** The distributions run here are temporary as the results change every time the code gets executed. The findings stated below are based on the values found at that time..

# %% [markdown]
# ###'Income':

# %% [markdown]
# We'll start with the column 'Income'.
#
# We'll use Gamma Distribution for the column 'Income' as it is a generalization of the exponential distribution and is used to model the waiting time until a Poisson process reaches a certain number of events.

# %%
# !pip install scipy

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate random data for 'Income' column
mean_income = 51963.46  # Mean value for Income
std_dev_income = 21405.89  # Standard deviation for Income
num_samples = 1000  # Number of samples

# Generate random data points following a normal distribution
income_data = np.random.normal(mean_income, std_dev_income, num_samples)

# Plotting the histogram of the generated data
plt.hist(income_data, bins=30, density=True, alpha=0.6, color='b', edgecolor='black')

# Plotting the normal distribution curve
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean_income, std_dev_income)
plt.plot(x, p, 'k', linewidth=2)

# Adding labels and title
plt.xlabel('Income')
plt.ylabel('Probability Density')
plt.title('Normal Distribution of Income')
plt.grid(True)
plt.show()

# %% [markdown]
# The peak of the histogram and the highest point of the normal curve represents the central tendency of the income data, which is the mean income value i.e 51963.46 here. This is the average income for the dataset.
#
# The width of the histogram and the standard deviation of the normal curve indicate the spread or variability of income values around the mean. The wider histogram and a larger standard deviation of 21405.89 suggests the income values are more spread out from the mean.

# %% [markdown]
# ###'Complain':

# %% [markdown]
# Next, we are going to check what is the probabilty of getting a 100% no-complaint rate, from 99% in the past 2 years for the column 'Complain' using the Poisson distribution as the Poisson distribution models the number of events occurring in a fixed interval of time or space when the events are rare and random.

# %%
from scipy.stats import poisson
import numpy as np

#mean/avg and percentage of complaints:
avg=np.mean(df['Complain'])
perc=round(avg,2)*100
print(f'The no. of complaints in the past 2 years: {perc:.2f}%')

#The probabilty of average complaints going from 1% to 0:
avg=0.01
r=0
ans=poisson.pmf(r,avg)*100
print(f'The probabilty of average complaints going from 1% to 0: {ans:.2f}%')
# Out:
# The no. of complaints in the past 2 years: 1.00%
# The probabilty of average complaints going from 1% to 0: 99.00%

# %% [markdown]
# Thus, using the Poisson distribution, we can see that there is a probabilty of 0.99 or 99% chance of getting 100% no-complain rate in the next 2 years if the company follows this trend.

# %% [markdown]
# ###'Kidhome' and 'Teenhome':

# %% [markdown]
# For these 2 columns, we are going to use Hypergeometric distribution as it models the probability of obtaining a certain number of successes in a fixed number of draws without replacement from a finite population of two types of items.

# %% [markdown]
# Let's assume a situation where the company is holding an ad campaign with the existing customer base to increase their market growth.
#
# What is the probability of having 4 customers with small children ('Kidhome') and 3 customers with teenage children ('Teenhome') in a sample of size 10, using the hypergeometric distribution.

# %%
#counting the no. of customers with kids and teens:
count_kid=0
count_teen=0

for i in df['Kidhome']:
  if i!=0:
    count_kid+=1
  else:
    pass

for j in df['Teenhome']:
  if j!=0:
    count_teen+=1
  else:
    pass

print(f"No. of customers with kids:  {count_kid}")
print(f"No. of customers with teens: {count_teen}")
# Out:
# No. of customers with kids:  946
# No. of customers with teens: 1082

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import hypergeom

# Total number of customers
total_customers = 2240

# Number of customers with small children
customers_with_kids = 946

# Number of customers with teenagers
customers_with_teens = 1082

# Sample size for the marketing campaign
sample_size = 10

# Number of customers with small children we want in our sample
kidhome_desired = 4

# Number of customers with teenagers we want in our sample
teenhome_desired = 3

# Hypergeometric distribution for 'Kidhome'
kidhome_dist = hypergeom(total_customers, customers_with_kids, sample_size)

# Hypergeometric distribution for 'Teenhome'
teenhome_dist = hypergeom(total_customers, customers_with_teens, sample_size)

# Probability of getting the desired number of customers with small children
kidhome_prob = kidhome_dist.pmf(kidhome_desired)

# Probability of getting the desired number of customers with teenagers
teenhome_prob = teenhome_dist.pmf(teenhome_desired)

# Print the probabilities
print("Probability of {} customers with small children in a sample of {}: {:.4f}".format(kidhome_desired, sample_size, kidhome_prob))
print("Probability of {} customers with teenagers in a sample of {}: {:.4f}".format(teenhome_desired, sample_size, teenhome_prob))

# Plot the distributions
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Plot for 'Kidhome'
x = np.arange(0, sample_size+1)
ax[0].plot(x, kidhome_dist.pmf(x), 'bo', ms=8, label='Kidhome PMF')
ax[0].vlines(x, 0, kidhome_dist.pmf(x), colors='b', lw=5, alpha=0.5)
ax[0].set_title('Hypergeometric Distribution for Kidhome')
ax[0].set_xlabel('Number of Customers with Small Children')
ax[0].set_ylabel('Probability')
ax[0].legend()

# Plot for 'Teenhome'
ax[1].plot(x, teenhome_dist.pmf(x), 'ro', ms=8, label='Teenhome PMF')
ax[1].vlines(x, 0, teenhome_dist.pmf(x), colors='r', lw=5, alpha=0.5)
ax[1].set_title('Hypergeometric Distribution for Teenhome')
ax[1].set_xlabel('Number of Customers with Teen Children')
ax[1].set_ylabel('Probability')
ax[1].legend()
# Out:
# Probability of 4 customers with small children in a sample of 10: 0.2488
# Probability of 3 customers with teenagers in a sample of 10: 0.1333

# %% [markdown]
# **Probability of 10 customers with small children (0.2488):**
#
# This means that there is approximately a **24.88%** chance of selecting exactly 10 customers with small children in a random sample of 50 customers from the total population of customers.

# %% [markdown]
# **Probability of 5 customers with teenagers (0.1333):**
#
# This means that there is approximately a **13.33%** chance of selecting exactly 5 customers with teenagers in a random sample of 50 customers from the total population of customers.

# %% [markdown]
# ###'NumDealsPurchases':

# %% [markdown]
# As we saw earlier, the average number of purchases made with a discount is approximately '2.33' which when compared to the average of '5.79' for 'NumStorePurchase', is very low..

# %%
df['NumDealsPurchases'].sum()
# Out:
# 5204

# %% [markdown]
# Let's see whether increasing the discount rate will lead to better amount of purchases using the binomial distribution.
#
# Let's assume the following scenario:
#
# We have a total of 5204 purchases.
#
# The historical probability of a customer making a purchase with a deal (success) is 0.5 (50%).
# We want to determine the probability of having a certain number of successful purchases (purchases with a deal) out of these 5204 purchases, under the assumption that the probability of success remains at 0.5.
#
# We will calculate the probabilities for different scenarios:
#
# Probability of 2602 or more successful purchases (with the current 50% probability).
#
# Probability of 3122 or more successful purchases (with an increased 60% probability).
#
# Probability of 3642 or more successful purchases (with an increased 70% probability).

# %%
from scipy.stats import binom

# Total number of purchases
total_purchases = 5204

# Historical probability of a purchase with a deal (success)
current_probability = 0.5  # 50%

# New probabilities to test
new_probabilities = [0.6, 0.7]  # 60% and 70%

# Define the scenarios
scenarios = [
    {"name": "2602 or more purchases (current probability)", "num_successes": 2602},
    {"name": "3122 or more purchases (60% probability)", "num_successes": int(total_purchases * 0.6)},
    {"name": "3642 or more purchases (70% probability)", "num_successes": int(total_purchases * 0.7)}
]

# Calculate probabilities for each scenario
for scenario in scenarios:
    # Probability of success for the scenario
    p = current_probability if "current" in scenario["name"] else new_probabilities[new_probabilities.index(0.6)+1]

    # Probability mass function (PMF) for the binomial distribution
    probability = 1 - binom.cdf(scenario["num_successes"] - 1, total_purchases, p)

    print(f"Probability of {scenario['name']}: {probability:.4f}")
# Out:
# Probability of 2602 or more purchases (current probability): 0.5055
# Probability of 3122 or more purchases (60% probability): 1.0000
# Probability of 3642 or more purchases (70% probability): 0.5165

# %% [markdown]
# 1. **Probability of 2602 or more purchases (current probability 50%) - 0.5055:**
#
#   This means that there is approximately a 50.55% chance of observing 2602 or more successful purchases (purchases with a deal) out of 5204 total purchases, with the current probability of success being 50%.
#   In practical terms, if the historical probability of a customer making a purchase with a deal remains at 50%, there is a 50.55% chance of observing at least 2602 successful purchases out of 5204 total.
#
# 2. **Probability of 3122 or more purchases (60% probability) - 1.0000:**
#
#   This probability is 1.0000, which means there is a 100% chance of observing 3122 or more successful purchases out of 5204 total purchases if the probability of success increases to 60%.
#   In other words, with a 60% probability of a customer making a purchase with a deal, it is guaranteed (100% probability) that there will be at least 3122 successful purchases out of 5204 total.
#
# 3. **Probability of 3642 or more purchases (70% probability) - 0.5165:**
#
#   This means that there is approximately a 51.65% chance of observing 3642 or more successful purchases out of 5204 total purchases if the probability of success increases to 70%.
#   In practical terms, with a 70% probability of a customer making a purchase with a deal, there is a 51.65% chance of observing at least 3642 successful purchases out of 5204 total.
#
#
#   In conclusion, increasing the discount to achieve a higher probability of a customer making a purchase with a deal can significantly increase the number of successful purchases. However, increasing the probability of success to 70% does not significantly increase the probability of observing more than 3642 successful purchases compared to the 60% probability scenario.

# %% [markdown]
# ###'NumCatalogPurchases':

# %% [markdown]
# As the average for purchases through catalog were similar to purchases with discount, we'll calculate the probability whether increasing the discount and offers in catalogues will increase the sales or not.

# %%
df['NumCatalogPurchases'].sum()
# Out:
# 5962

# %% [markdown]
# Let's assume the following scenario:
#
# We have a total of 5962 purchases.
#
# The historical probability of a customer making a purchase with a deal (success) is 0.5 (50%). We want to determine the probability of having a certain number of successful purchases (purchases with a deal) out of these 5962 purchases, under the assumption that the probability of success remains at 0.5.
#
# We will calculate the probabilities for different scenarios:
#
# Probability of 596 or more successful purchases (with the current 10% probability).
#
# Probability of 1192 or more successful purchases (with an increased 20% probability).
#
# Probability of 1788 or more successful purchases (with an increased 30% probability).

# %%
from scipy.stats import binom

# Total number of purchases
total_purchases = 5962

# Historical probability of a purchase with a deal (success)
current_probability = 0.1  # 10%

# New probabilities to test
new_probabilities = [0.2, 0.3]  # 20% and 30%

# Define the scenarios
scenarios = [
    {"name": "596 or more purchases (current probability)", "num_successes": 596},
    {"name": "1192 or more purchases (20% probability)", "num_successes": int(total_purchases * 0.2)},
    {"name": "1788 or more purchases (30% probability)", "num_successes": int(total_purchases * 0.3)}
]

# Calculate probabilities for each scenario
for scenario in scenarios:
    # Probability of success for the scenario
    p = current_probability if "current" in scenario["name"] else new_probabilities[new_probabilities.index(0.2)+1]

    # Probability mass function (PMF) for the binomial distribution
    probability = 1 - binom.cdf(scenario["num_successes"] - 1, total_purchases, p)

    print(f"Probability of {scenario['name']}: {probability:.4f}")
# Out:
# Probability of 596 or more purchases (current probability): 0.5098
# Probability of 1192 or more purchases (20% probability): 1.0000
# Probability of 1788 or more purchases (30% probability): 0.5116

# %% [markdown]
# This shows that:
#
# **Probability of 1192 or more purchases (20% probability) - 1.0000:**
#
# The probability here is 1.0000, which means there is a 100% chance of observing 1192 or more successful purchases out of 5962 total purchases if the probability of success increases to 20%. In other words, with a 20% probability of a customer making a purchase with a deal, it is guaranteed (100% probability) that there will be at least 1192 successful purchases out of 5962 total.
#
# So, in conclusion, we can say that increasing the discount by 20% can affect the purchases made through the catalogue greatly in a positive way!!

# %% [markdown]
# ###'Recency':

# %% [markdown]
# For the column 'Recency', the average number of days between each purchase is 49 days.
#
# Let's find out what is the probability of reducing the number of days using Exponential Distribution.

# %%
import numpy as np

# Average number of days between purchases
average_days = 49

# Calculate the rate parameter (lambda) for the exponential distribution
rate_parameter = 1 / average_days

# Number of days we are interested in
x = 40

# Calculate the probability using the exponential distribution CDF
probability = 1 - np.exp(-rate_parameter * x)

print(f"Probability of the time between purchases being less than or equal to {x} days: {probability:.4f}")
# Out:
# Probability of the time between purchases being less than or equal to 40 days: 0.5579

# %% [markdown]
# We can see there is a 55% chance of reducing this figure to 40 days.
#
# But what if we increase the discounts by 20%?
# Will it lead to a reduce in days?
#
# For this, we will use the concept of 'hazard rate' in context to exponential distribution.
#
# The hazard rate is the instantaneous rate at which an event (in this case, a purchase) occurs, given that it has not occurred before. In the context of purchases, it represents the rate at which customers are making purchases.
#
# The hazard rate for the exponential distribution is given by:
#
# λ = 1 / average time between purchases

# %%
import numpy as np

# Original average number of days between purchases
original_average_days = 49

# Original rate parameter (lambda) for the exponential distribution
original_rate_parameter = 1 / original_average_days

# Number of days we are interested in
x = 40

# Calculate the probability using the original rate parameter
original_probability = 1 - np.exp(-original_rate_parameter * x)

# Increase in discounts (hypothetical)
discount_increase_factor = 1.2

# New rate parameter after increasing discounts
new_rate_parameter = original_rate_parameter / discount_increase_factor

# Calculate the new probability using the new rate parameter
new_probability = 1 - np.exp(-new_rate_parameter * x)

print(f"Original Probability (average 49 days): {original_probability:.4f}")
print(f"New Probability (adjusted with increased discounts): {new_probability:.4f}")
# Out:
# Original Probability (average 49 days): 0.5579
# New Probability (adjusted with increased discounts): 0.4935

# %% [markdown]
# Thus, we can see even if we increase the discount rates by 20%, there is only a 49% chance the customer turnout rate will improve..

# %% [markdown]
# ###'MntFishProducts':

# %% [markdown]
# From our earlier observations, we saw the average for amount of fishes purchased was very low when compared to other food categories for the past 2 years.
# Using Gamma Distribution, we are going to analyze and calculate the probability of whether the sales will improve in the next 2 years or not.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma

# Historical data for 'MntFishProducts' column (in thousands)
mnt_fish_data = df['MntFishProducts']

# Estimate parameters of the Gamma distribution from the data
shape, loc, scale = gamma.fit(mnt_fish_data)

# Define the time frame for the next 2 years (24 months)
time_frame_months = 24

# Generate random samples from the Gamma distribution for the next 2 years
random_samples = gamma.rvs(shape, loc=loc, scale=scale, size=time_frame_months)

# Calculate the average spending for each month
average_spending = np.mean(random_samples)

# Plot the histogram of random samples
plt.hist(random_samples, bins=15, density=True, alpha=0.6, color='b', edgecolor='black')
plt.axvline(average_spending, color='r', linestyle='dashed', linewidth=1.5, label=f'Average Spending: {average_spending:.2f}')
plt.xlabel('Amount Spent on Fishes (in thousands)')
plt.ylabel('Probability Density')
plt.title('Predicted Distribution of Amount Spent on Fishes for Next 2 Years')
plt.legend()
plt.grid(True)
plt.show()

print(f"Estimated Average Spending on Fishess for the Next 2 Years: {average_spending:.2f} (in thousands)")
# Out:
# Estimated Average Spending on Fishess for the Next 2 Years: 26.51 (in thousands)

# %% [markdown]
# From the above graph, we can see the mean average has decreased from 37.54 to 24.92 in the span of 2 years showcasing a possible reduction in the future sales of Fishes. That is a 66.38% decrease in the total sales within a span of 2 years.
#
# It would be suggested to the company to offer some considerable discount to improve on this predicted probability of potential loss.

# %% [markdown]
# ###'MntFruits':

# %% [markdown]
# From our earlier observations, we saw the average for amount of fruits purchased was the lowest among all the food categories for the past 2 years.
# Using Gamma Distribution, we are going to analyze and calculate the probability of whether the sales will improve in the next 2 years or not.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma

# Historical data for 'MntFruits' column (in thousands)
mnt_fruits_data = df['MntFruits']

# Estimate parameters of the Gamma distribution from the data
shape, loc, scale = gamma.fit(mnt_fruits_data)

# Define the time frame for the next 2 years (24 months)
time_frame_months = 24

# Generate random samples from the Gamma distribution for the next 2 years
random_samples = gamma.rvs(shape, loc=loc, scale=scale, size=time_frame_months)

# Calculate the average spending for each month
average_spending = np.mean(random_samples)

# Plot the histogram of random samples
plt.hist(random_samples, bins=15, density=True, alpha=0.6, color='b', edgecolor='black')
plt.axvline(average_spending, color='r', linestyle='dashed', linewidth=1.5, label=f'Average Spending: {average_spending:.2f}')
plt.xlabel('Amount Spent on Fruits (in thousands)')
plt.ylabel('Probability Density')
plt.title('Predicted Distribution of Amount Spent on Fruits for Next 2 Years')
plt.legend()
plt.grid(True)
plt.show()

print(f"Estimated Average Spending on Fruits for the Next 2 Years: {average_spending:.2f} (in thousands)")
# Out:
# Estimated Average Spending on Fruits for the Next 2 Years: 16.97 (in thousands)

# %% [markdown]
# From the above graph, we can see the mean average has decreased from 26.31 to 15.18 in the span of 2 years showcasing a possible reduction in the future sales of Fruits. That is a 57.69% decrease in the total sales within a span of 2 years.
#
# It would be suggested to the company to offer some considerable discount to improve on this predicted probability of potential loss.

# %% [markdown]
# ###'MntMeatProducts':

# %% [markdown]
# From our earlier observations, we saw the average for amount of Meat products purchased has been the second highest than when compared to other food categories for the past 2 years. Using Gamma Distribution, we are going to analyze and calculate the probability of whether the sales will further improve or plummet in the next 2 years.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma

# Historical data for 'MntMeatProducts' column (in thousands)
mnt_meat_data = df['MntMeatProducts']

# Estimate parameters of the Gamma distribution from the data
shape, loc, scale = gamma.fit(mnt_meat_data)

# Define the time frame for the next 2 years (24 months)
time_frame_months = 24

# Generate random samples from the Gamma distribution for the next 2 years
random_samples = gamma.rvs(shape, loc=loc, scale=scale, size=time_frame_months)

# Calculate the average spending for each month
average_spending = np.mean(random_samples)

# Plot the histogram of random samples
plt.hist(random_samples, bins=15, density=True, alpha=0.6, color='b', edgecolor='black')
plt.axvline(average_spending, color='r', linestyle='dashed', linewidth=1.5, label=f'Average Spending: {average_spending:.2f}')
plt.xlabel('Amount Spent on Meat (in thousands)')
plt.ylabel('Probability Density')
plt.title('Predicted Distribution of Amount Spent on Meat for Next 2 Years')
plt.legend()
plt.grid(True)
plt.show()

print(f"Estimated Average Spending on Meat for the Next 2 Years: {average_spending:.2f} (in thousands)")
# Out:
# Estimated Average Spending on Meat for the Next 2 Years: 162.77 (in thousands)

# %% [markdown]
# From the above graph, we can see the mean average has increased from 167.02 to 296.30 in the span of 2 years showing an excellent improvement in the future sales of Meat products. This is a 46.43% increase in the total sales within a span of 2 years.

# %% [markdown]
# ###'MntSweetProducts':

# %% [markdown]
# From our earlier observations, we saw the average for amount of sweets purchased was very low at only 27.07 units when compared to all the food categories for the past 2 years.
# Using Gamma Distribution, we are going to analyze and calculate the probability of whether the sales will improve in the next 2 years or not.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma

# Historical data for 'MntSweetProducts' column (in thousands)
mnt_sweet_data = df['MntSweetProducts']

# Estimate parameters of the Gamma distribution from the data
shape, loc, scale = gamma.fit(mnt_sweet_data)

# Define the time frame for the next 2 years (24 months)
time_frame_months = 24

# Generate random samples from the Gamma distribution for the next 2 years
random_samples = gamma.rvs(shape, loc=loc, scale=scale, size=time_frame_months)

# Calculate the average spending for each month
average_spending = np.mean(random_samples)

# Plot the histogram of random samples
plt.hist(random_samples, bins=15, density=True, alpha=0.6, color='b', edgecolor='black')
plt.axvline(average_spending, color='r', linestyle='dashed', linewidth=1.5, label=f'Average Spending: {average_spending:.2f}')
plt.xlabel('Amount Spent on Sweets (in thousands)')
plt.ylabel('Probability Density')
plt.title('Predicted Distribution of Amount Spent on Sweets for Next 2 Years')
plt.legend()
plt.grid(True)
plt.show()

print(f"Estimated Average Spending on Sweets for the Next 2 Years: {average_spending:.2f} (in thousands)")
# Out:
# Estimated Average Spending on Sweets for the Next 2 Years: 12.49 (in thousands)

# %% [markdown]
# From the above graph, we can see the mean average has decreased from 27.07 to an all-time low of 6.88 in the span of 2 years showcasing a possible reduction in the future sales of Sweets. That is a 75.59% decrease in the total sales within a span of 2 years.
#
# It would be suggested to the company to offer some considerable discount to improve on this predicted probability of potential loss though it could also be due to customers adopting a healthier lifestyle leading to less sales in general.

# %% [markdown]
# ###'MntWines':

# %% [markdown]
# From our earlier observations, we saw the average for amount of Wine purchased has been the highest when compared to other food categories for the past 2 years. Using Gamma Distribution, we are going to analyze and calculate the probability of whether the sales will further improve or plummet in the next 2 years.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma

# Historical data for 'MntWines' column (in thousands)
mnt_wine_data = df['MntWines']

# Estimate parameters of the Gamma distribution from the data
shape, loc, scale = gamma.fit(mnt_meat_data)

# Define the time frame for the next 2 years (24 months)
time_frame_months = 24

# Generate random samples from the Gamma distribution for the next 2 years
random_samples = gamma.rvs(shape, loc=loc, scale=scale, size=time_frame_months)

# Calculate the average spending for each month
average_spending = np.mean(random_samples)

# Plot the histogram of random samples
plt.hist(random_samples, bins=15, density=True, alpha=0.6, color='b', edgecolor='black')
plt.axvline(average_spending, color='r', linestyle='dashed', linewidth=1.5, label=f'Average Spending: {average_spending:.2f}')
plt.xlabel('Amount Spent on Wine (in thousands)')
plt.ylabel('Probability Density')
plt.title('Predicted Distribution of Amount Spent on Wine for Next 2 Years')
plt.legend()
plt.grid(True)
plt.show()

print(f"Estimated Average Spending on Wine for the Next 2 Years: {average_spending:.2f} (in thousands)")
# Out:
# Estimated Average Spending on Wine for the Next 2 Years: 156.23 (in thousands)

# %% [markdown]
# From the above graph, we can see the mean average has decreased from 304.07 to 200.54 in the span of 2 years showing a massive decline in the future sales of Wine products. This is a 34.05% decrease in the total sales within a span of 2 years.
#
# Although the sales should rise for wine products as time passes due to its rarity and antiqueness, we see a negative trend here for the next 2 years.
#
# This could also be due to the increase in prices because of its antiqueness as time passes on.

# %% [markdown]
# ###'MntGoldProds':

# %% [markdown]
# From our earlier observations, we saw the average for amount of gold products purchased in the past 2 years.
# Using Gamma Distribution, we are going to analyze and calculate the probability of whether the sales will improve in the next 2 years or not.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma

# Historical data for 'MntGoldProds' column (in thousands)
mnt_gold_data = df['MntGoldProds']

# Estimate parameters of the Gamma distribution from the data
shape, loc, scale = gamma.fit(mnt_gold_data)

# Define the time frame for the next 2 years (24 months)
time_frame_months = 24

# Generate random samples from the Gamma distribution for the next 2 years
random_samples = gamma.rvs(shape, loc=loc, scale=scale, size=time_frame_months)

# Calculate the average spending for each month
average_spending = np.mean(random_samples)

# Plot the histogram of random samples
plt.hist(random_samples, bins=15, density=True, alpha=0.6, color='b', edgecolor='black')
plt.axvline(average_spending, color='r', linestyle='dashed', linewidth=1.5, label=f'Average Spending: {average_spending:.2f}')
plt.xlabel('Amount Spent on Gold (in thousands)')
plt.ylabel('Probability Density')
plt.title('Predicted Distribution of Amount Spent on Gold for Next 2 Years')
plt.legend()
plt.grid(True)
plt.show()

print(f"Estimated Average Spending on Gold for the Next 2 Years: {average_spending:.2f} (in thousands)")
# Out:
# Estimated Average Spending on Gold for the Next 2 Years: 43.32 (in thousands)

# %% [markdown]
# From the above graph, we can see the mean average has increased from 44.04 to 61.37 in the span of 2 years showcasing a possible increase in the future sales of Gold Products. That is a 28.24% increase in the total sales within a span of 2 years.
#
# This when including the fact that Gold's rate has been increasing can give an even higher value and units spent than this probability.

# %% [markdown]
# ###'Year_birth':

# %% [markdown]
# We'll use Gamma Distribution for the column 'Year_birth' to see where the values are normally distributed further helping us to analyse the common purchasing age of people as it is a generalization of the exponential distribution and is used to model the waiting time until a Poisson process reaches a certain number of events.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate data for 'Year_birth' column
mean_year_birth = 1968  # Mean value for Year_birth
std_dev_year_birth = 11.98  # Standard deviation for Year_birth
num_samples = 1000  # Number of samples

# Generate random data points following a normal distribution
year_birth_data = np.random.normal(mean_year_birth, std_dev_year_birth, num_samples)

# Plotting the histogram of the generated data
plt.hist(year_birth_data, bins=30, density=True, alpha=0.6, color='b', edgecolor='black')

# Plotting the normal distribution curve
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean_year_birth, std_dev_year_birth)
plt.plot(x, p, 'k', linewidth=2)

# Adding labels and title
plt.xlabel('Year_birth')
plt.ylabel('Probability Density')
plt.title('Normal Distribution of Year_birth')
plt.grid(True)
plt.show()

# %% [markdown]
# The peak of the histogram and the highest point of the normal curve represents the central tendency of the year_birth data, which is the mean value of the year 1968 here. This is the average year of customers purchasing products for the dataset.
#
# An std of 11.98 means that, on average, the birth years of the customers are about 11.98 years away from the mean birth year. This suggests that the age range of customers in the dataset is quite broad.

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# ###Correlation Analysis:

# %% [markdown]
# We'll calculate the correlation matrix to see how different variables are correlated with each other and with spending habits. With this, we will identify strong correlations between spending on different product categories and customer characteristics.

# %% [markdown]
# A value of **'1'** shows maximum correlation shown by red colour whereas a value of **'-1'** shows the least correlation between the 2 variables which is denoted with the blue colour.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(filepath)

# Correlation matrix
correlation_matrix = df.corr()
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-53-b414aec6de3f>:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# From the above Correlation Analysis Graph, we can see:

# %% [markdown]
# 1.   There is a **0.72** correlation between column 'NumCatalogPurchases' and 'MntMeatProducts'. This implies that customers who make more catalog purchases are likely to spend more on meat products. These 2 variables have a very positive linear relationship.
#
# 2.   There is a **0.64** correlation between column 'MntWines' and 'NumCatalogPurchases', 'NumStorePurchases'. This implies that customers purchase wine equally from both the stores and catalogues. These 3 variables have a relatively positive linear relationship.
#
# 3.   There is a **0.58** correlation between column 'Income' and 'MntWines'. This implies that the 2 variables are relatively correlated meaning as the income increases, the purchase of wine will also increase. This can also mean that the product category 'Wine' can be treated as a luxury item.
#
# 4. We see the same correlation of **0.58** correlation between column 'Income' and 'MntMeatProducts'. This shows that similar to wine, the amount of purchases for meat products increase as the
# income increases. This shows that both the variables are relatively proportional. This is further backed by the correlation of **0.58** for the columns 'MntMeatProducts' and 'MntWines'.
#
# 5. There is a **0.59** correlation between column 'Income' and 'NumCatalogPurchases'. This implies that the 2 variables are greatly correlated meaning as the income increases, the purchase of catalogues will also increase. This also shows that higher amounts of both meat and wine are purchased through catalogues showing people with higher income purchase catalogues thus further purchasing more expensive products like meat and wine.
#
# 6. A correlation of **0.59** between 'MntFishProducts' and 'MntFruits' indicates a moderately strong positive linear relationship between the amount spent on fish products and the amount spent on fruits. Customers who spend more on fish products are likely to also spend more on fruits. This could indicate certain dietary preferences or shopping habits.
#
# 7. We also see a negative correlation of **-0.55** between 'Income' and 'NumWebVisitsMonth'. This means that they aren't correlated and people from all income groups visit the web for Web Purchases.
#
# 8. There being less than 1% complaints in the past 2 years shows that the column 'Complain' is negatively correlated to all of the columns and isn't proportional.
#
# 9. We see a correlation of **0.45** between column 'Kidhome' and 'NumWebVisitsMonth'. This shows that a great portion of web visits are from kids. Both the variables are relatively proportional.

# %% [markdown]
# ###Visualization:

# %% [markdown]
# We'll now see how purchases are distributed among different levels of income and different segments of customers.

# %% [markdown]
# ####Income vs. Spending on Wine:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = df[df['Income'] <= 600000]
# Scatter plot of Income vs. Spending on Wine:
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['Income'], y=df['MntWines'], hue='Marital_Status', data=df)
plt.title('Income vs. Spending on Wine')
plt.xlabel('Income')
plt.ylabel('Spending on Wine')
plt.show()

# %%
# Calculate total wines purchased for each marital status
total_wines_per_marital = df.groupby('Marital_Status')['MntWines'].sum()

# Calculate percentage of wines purchased for each marital status
percentage_wines_per_marital = (total_wines_per_marital / total_wines_per_marital.sum()) * 100
percentage_wines_per_marital.sort_values(ascending=False)
# Out:
# Marital_Status
# Married     38.010040
# Together    26.137080
# Single      20.296151
# Divorced    11.147300
# Widow        4.127063
# Absurd       0.105166
# YOLO         0.095256
# Alone        0.081944
# Name: MntWines, dtype: float64

# %% [markdown]
# We can see that the majority of people who purchased wines were from the 'Married' category, with the second highest being from the category 'Together'.
#
# The majority buying wines who spent the highest have an income of 40000-100000.
#
# The maximum amount spent goes upwards of 1400 showing that wines have different ranges but become quite a luxury item for being so expensive.

# %% [markdown]
# ####Income vs. Spending on Fruits:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = df[df['Income'] <= 600000]

# Scatter plot of Income vs. Spending on Fruits
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Income', y='MntFruits', hue='Marital_Status', data=df)
plt.title('Income vs. Spending on Fruits')
plt.xlabel('Income')
plt.ylabel('Spending on Fruits')
plt.show()

# %%
# Calculate total fruits purchased for each marital status
total_fruits_per_marital = df.groupby('Marital_Status')['MntFruits'].sum()

# Calculate percentage of fruits purchased for each marital status
percentage_fruits_per_marital = (total_fruits_per_marital / total_fruits_per_marital.sum()) * 100
percentage_fruits_per_marital.sort_values(ascending=False)
# Out:
# Marital_Status
# Married     37.644500
# Together    25.000428
# Single      21.989690
# Divorced    10.897227
# Widow        4.147900
# Absurd       0.289428
# Alone        0.020551
# YOLO         0.010276
# Name: MntFruits, dtype: float64

# %% [markdown]
# We can see that the majority of people who purchased fruits are also from the 'Married' category, with the second highest being from the category 'Together' showing that a family of 2 or more are more likely to purchase fruits.
#
# The majority buying fruits have an income of 60000-100000. The maximum spent was only around 200 showing that it is a normal product bought by all.

# %% [markdown]
# ####Income vs. Spending on Meat:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = df[df['Income'] <= 600000]
# Scatter plot of Income vs. Spending on Meat:
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['Income'], y=df['MntMeatProducts'], hue='Marital_Status', data=df)
plt.title('Income vs. Spending on Meat')
plt.xlabel('Income')
plt.ylabel('Spending on Meat')
plt.show()

# %%
# Calculate total Meat purchased for each marital status
total_meat_per_marital = df.groupby('Marital_Status')['MntMeatProducts'].sum()

# Calculate percentage of Meat purchased for each marital status
percentage_meat_per_marital = (total_meat_per_marital / total_meat_per_marital.sum()) * 100
percentage_meat_per_marital.sort_values(ascending=False)
# Out:
# Marital_Status
# Married     37.262495
# Together    25.768758
# Single      23.527949
# Divorced     9.417233
# Widow        3.806294
# Absurd       0.168898
# YOLO         0.027024
# Alone        0.021349
# Name: MntMeatProducts, dtype: float64

# %% [markdown]
# We can see that the majority of people who purchased Meat were from the 'Married' category, with the second highest being from the category 'Together'.
#
# The majority buying Meat who spent the highest have an income of 60000-100000.
#
# The maximum amount spent reaches around 1000 with the majority spending being around 500 for meat products.

# %% [markdown]
# ####Income vs. Spending on Gold:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = df[df['Income'] <= 600000]

# Scatter plot of Income vs. Spending on Gold
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Income', y='MntGoldProds', hue='Marital_Status', data=df)
plt.title('Income vs. Spending on Gold')
plt.xlabel('Income')
plt.ylabel('Spending on Gold')
plt.show()

# %%
# Calculate total Gold purchased for each marital status
total_gold_per_marital = df.groupby('Marital_Status')['MntGoldProds'].sum()

# Calculate percentage of Gold purchased for each marital status
percentage_gold_per_marital = (total_gold_per_marital / total_gold_per_marital.sum()) * 100
percentage_gold_per_marital.sort_values(ascending=False)
# Out:
# Marital_Status
# Married     37.693374
# Together    25.398553
# Single      20.938254
# Divorced    11.023970
# Widow        4.357645
# Absurd       0.418827
# YOLO         0.086229
# Alone        0.083149
# Name: MntGoldProds, dtype: float64

# %% [markdown]
# We can see that the majority of people who purchased gold are also from the 'Married' category, with the second highest being from the category 'Together' showing that couples are more likely to purchase gold when compared to the rest.
#
# Overall, the spending on Gold products is quite low where people prefer to spend 4-5 times more on wine than on gold. This shows the customers don't prefer buying gold as a product here.

# %% [markdown]
# ####Income vs. Spending on Fish:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = df[df['Income'] <= 600000]
# Scatter plot of Income vs. Spending on Fish:
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['Income'], y=df['MntFishProducts'], hue='Marital_Status', data=df)
plt.title('Income vs. Spending on Fish')
plt.xlabel('Income')
plt.ylabel('Spending on Fish')
plt.show()

# %%
# Calculate total Fish purchased for each marital status
total_fish_per_marital = df.groupby('Marital_Status')['MntFishProducts'].sum()

# Calculate percentage of Fish purchased for each marital status
percentage_fish_per_marital = (total_fish_per_marital / total_fish_per_marital.sum()) * 100
percentage_fish_per_marital.sort_values(ascending=False)
# Out:
# Marital_Status
# Married     36.446155
# Together    26.829502
# Single      21.897670
# Divorced     9.748552
# Widow        4.548125
# Absurd       0.492823
# Alone        0.027579
# YOLO         0.009593
# Name: MntFishProducts, dtype: float64

# %% [markdown]
# We can see that the majority of people who purchased Fish were from the 'Married' category, with the second highest being from the category 'Together'.
#
# The people buying Fish who spent the highest have an income of 0-100000. Since it ranges to such a broad income frame, it shows that fish is a normal commodity bought by everyone.
#
# The maximum amount spent reaches only around 250 showing that it is cheap and bought a lot.

# %% [markdown]
# ####Income vs. Spending on Sweets:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = df[df['Income'] <= 600000]

# Scatter plot of Income vs. Spending on Sweets
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Income', y='MntSweetProducts', hue='Marital_Status', data=df)
plt.title('Income vs. Spending on Sweets')
plt.xlabel('Income')
plt.ylabel('Spending on Sweets')
plt.show()

# %%
# Calculate total Sweets purchased for each marital status
total_sweets_per_marital = df.groupby('Marital_Status')['MntSweetProducts'].sum()

# Calculate percentage of Sweets purchased for each marital status
percentage_sweets_per_marital = (total_sweets_per_marital / total_sweets_per_marital.sum()) * 100
percentage_sweets_per_marital.sort_values(ascending=False)
# Out:
# Marital_Status
# Married     38.276985
# Together    25.093914
# Single      21.288922
# Divorced    10.388179
# Widow        4.805076
# Absurd       0.101845
# Alone        0.035061
# YOLO         0.010018
# Name: MntSweetProducts, dtype: float64

# %% [markdown]
# ####Income vs. Spending on Purchases through Catalog:

# %% [markdown]
# We can see that the majority of people who purchased fruits are also from the 'Married' category, with the second highest being from the category 'Together' showing that a family of 2 or more are more likely to purchase Sweets.
#
# The majority buying Sweets have an income of 0-100000. The maximum spent was only around 200 showing that it is a normal product bought by all.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = df[df['Income'] <= 600000]

# Scatter plot of Income vs. Purchases through Catalog
plt.figure(figsize=(8, 6))
sns.scatterplot(y='Income', x='NumCatalogPurchases', hue='Marital_Status', data=df)
plt.title('Income vs. Purchases through Catalog')
plt.ylabel('Income')
plt.xlabel('Purchases through Catalog')
plt.show()

# %%
# Calculate total purchases through catalog for each marital status
total_ncp_per_marital = df.groupby('Marital_Status')['NumCatalogPurchases'].sum()

# Calculate percentage of total purchases through catalog for each marital status
percentage_ncp_per_marital = (total_ncp_per_marital / total_ncp_per_marital.sum()) * 100
percentage_ncp_per_marital.sort_values(ascending=False)
# Out:
# Marital_Status
# Married     38.034546
# Together    26.027168
# Single      20.929063
# Divorced    10.397451
# Widow        4.293141
# Absurd       0.251551
# Alone        0.033540
# YOLO         0.033540
# Name: NumCatalogPurchases, dtype: float64

# %% [markdown]
# We can see that the majority of people who purchased through catalog are also from the 'Married' category, with the second highest being from the category 'Together' showing that a family of 2 or more are more likely to purchase a catalog.
#
# The majority buying Catalogues have an income of 0-100000. The maximum spent was only around 10 showing that catalogues are a normal product bought by all irrespective of the income.

# %% [markdown]
# ###Income vs. Marital Status:

# %% [markdown]
# We'll also analyse the relationship between the Marital status and Income.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of the plot
sns.set(style="whitegrid")

# Create the violin plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Marital_Status'], y=df['Income'], data=df, palette='muted')
plt.xlabel('Marital Status')
plt.ylabel('Income')
plt.title('Income Distribution by Marital Status')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-68-847a952f66c3>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Marital_Status'], y=df['Income'], data=df, palette='muted')

# %% [markdown]
# From the above graph, we can see the median income for the four categories- Divorced, Single, Married, Together stay the same at 40000-60000. The maximum income that is not considered an outlier is for the 'Single' category with income greater than 110000.

# %% [markdown]
# ###RFM:

# %% [markdown]
# RFM Analysis (Recency, Frequency, Monetary Value):
#
# Analyzes how recently a customer made a purchase (Recency), how often they purchase (Frequency), and how much they spend (Monetary Value).
#
# Segment customers into groups based on these RFM metrics: high spenders, loyal customers, new customers, etc.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(filepath)

# RFM Analysis
df['Total_Spent'] = df['MntFishProducts'] + df['MntMeatProducts'] + df['MntFruits'] + df['MntSweetProducts'] + df['MntWines'] + df['MntGoldProds']
rfm_df = df[['Recency', 'NumDealsPurchases', 'Total_Spent']]

# Standardize the variables
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Apply K-means clustering
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4, random_state=42)
rfm_df['Cluster'] = kmeans.fit_predict(rfm_df)

# Visualize the clusters
sns.scatterplot(x='Recency', y='Total_Spent', hue='Cluster', data=rfm_df, palette='viridis')
plt.title('RFM Clusters')
plt.xlabel('Recency')
plt.ylabel('Total Spent')
plt.show()

# Cluster Profiles
cluster_profiles = rfm_df.groupby('Cluster').mean()
print(cluster_profiles)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-69-ccfc283b2549>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm_df['Cluster'] = kmeans.fit_predict(rfm_df)
#            Recency  NumDealsPurchases  Total_Spent
# Cluster
# 0        47.195804           3.452214   572.790210
# 1        51.361404           1.533333  1753.589474
# 2        49.101584           2.109972   100.438024
# 3        49.523179           2.264901  1111.960265

# %% [markdown]
# ####The results of the RFM (Recency, Frequency, Monetary Value) analysis are presented in the table for each cluster:

# %% [markdown]
# **Cluster 0:**
#
# Recency: 47.20 days
#
# NumDealsPurchases: 3.45 deals
#
# Total_Spent: $572.79
#
# **Cluster 1:**
#
# Recency: 51.36 days
#
# NumDealsPurchases: 1.53 deals
#
# Total_Spent: $1753.59
#
# **Cluster 2:**
#
# Recency: 49.10 days
#
# NumDealsPurchases: 2.11 deals
#
# Total_Spent: $100.44
#
# **Cluster 3:**
#
# Recency: 49.52 days
#
# NumDealsPurchases: 2.26 deals
#
# Total_Spent: $1111.96

# %% [markdown]
# ####**Interpretation:**

# %% [markdown]
# **Recency:**
#
#   1. Cluster 0 has the lowest recency (47.20 days), meaning customers in this cluster made their most recent purchases relatively recently.
#
#
#   2. Cluster 1 has the highest recency (51.36 days), indicating that customers in this cluster made their most recent purchases quite a bit further back in time.
#
# 3. Clusters 2 and 3 have similar recency values, indicating that customers in these clusters made their most recent purchases recently, but not as recently as Cluster 0.
# NumDealsPurchases
#
# **(Number of Deals Purchased):**
#
# 1. Cluster 1 has the lowest average number of deals purchased (1.53 deals), suggesting that customers in this cluster are less responsive to deals or promotions.
#
# 2. Cluster 0 and Cluster 3 have similar values for deals purchased, indicating that customers in these clusters are more responsive to deals.
#
# 3. Cluster 2 falls in between, with a moderate number of deals purchased.
#
# **Total_Spent:**
#
# 1. Cluster 1 has the highest average total spent ($1753.59), indicating that customers in this cluster are high spenders.
#
# 2. Cluster 0 and Cluster 3 have moderate total spent values, indicating these clusters contain customers with moderate spending habits.
#
# 3. Cluster 2 has the lowest average total spent ($100.44), suggesting that customers in this cluster are lower spenders.

# %% [markdown]
# ####**Insights:**

# %% [markdown]
# 1. **Cluster 1 (High Spenders):**
#
#   Customers in Cluster 1 have the highest total spent, indicating they are high-value customers.
#   However, they also have the highest recency, meaning they haven't made purchases recently.
#   Strategies to retain these customers might include targeted promotions or loyalty programs to encourage repeat purchases.
#
# 2. **Cluster 0 and Cluster 3 (Moderate Spenders):**
#
#   These clusters have moderate total spent and relatively lower recency compared to Cluster 1.
#   They are responsive to deals, as indicated by the number of deals purchased.
#   Targeted promotions and incentives can help encourage more frequent purchases from these segments.
#
# 3. **Cluster 2 (Low Spenders):**
#
#   Customers in Cluster 2 have the lowest total spent and moderate recency.
#   They are not very responsive to deals compared to other clusters.
#   Strategies to increase spending from this segment might involve targeted marketing to showcase value and benefits.

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# ###**Findings:**

# %% [markdown]
# 1. This shows that only 14.91% of customers accepted the job in the last campaign.
#
# 2. The most common level of education among customers is: Graduation
#
# 3. The most common marital status among the customers are Married people.
#
# 4. The birth year of customers in your dataset is around 1969.
#
# 5. On average, the yearly income of customers in our dataset is approximately $51,963.46.
#
# 6. The highest average is for the column 'NumStorePurchase' which shows that people still prefer going to the store to purchase items when compared to doing their purchases online.
#
# 7. People on average purchase every 49 days. There is only 55% chance of reducing this figure to 40 days. Even if we were to increase the discounts by 20%, there is only a 49% chance the customer turnout rate will improve.
#
# 8. The customer service is excellent as the majority of customers (99%) did not file a complaint in the last 2 years.
#
# 9. If the company holds an ad campaign with the existing customer base to increase their market growth, the probability of having 4 customers with small children ('Kidhome') is 24.8% and for 3 customers with teenage children ('Teenhome') in a sample of size 10 is 13.3%.
#
# 10. The average for the column 'NumDealsPurchase' is the lowest indicating that the customers are still not doing high amount of purchases when discounts are being offered. One possible reason could be that the offers are not that great or attractive for them to purchase in bulk..
#
#   Since the historical probability of a customer making a purchase with a deal (success) is 0.5 (50%). We seeked to determine the probability of having a certain number of successful purchases under the assumption that the probability of success remains at 0.5.
#
#   We found that there is a 100% chance of observing 3122 or more successful purchases out of 5204 total purchases if the probability of success increases to 60%.
#
#   This means increasing the discount to achieve a higher probability of a customer making a purchase with a deal can significantly increase the number of successful purchases.
#
# 11. Similarly, in the case of 'NumCatalogPurchases', there is a 100% probability that there will be at least 1192 successful purchases out of 5962 total if we increase the probability of success by 20%. meaning increasing the discount by 20% can affect the purchases made through the catalogue greatly in a positive way!!
#
# 12. The sales for Fishes will only continue to decrease for the next 2 years if the same system is followed by the company. The probability of 66.38% decrease in total sales will lead to heavy losses. The people buying Fish who spent the highest have an income of 0-100000. Since it ranges to such a broad income frame, it shows that fish is a normal commodity bought by everyone. The maximum amount spent reaches only around 250 showing that it is cheap and bought a lot.
#
# 13. The sales for Fruits will continue to decrease as well for the next 2 years with a probability of 57.69% decrease in total sales which can will lead to heavy losses. The majority buying fruits have an income of 60000-100000. The maximum spent was only around 200 showing that it is a normal product bought by all.
#
# 14. The sales of Meat products can see a great increase by 46.43% for the next 2 years which is a great sign showing the possible high demand for meat products in the foreseeable future. The majority of people who purchased Meat were from the 'Married' category, with the second highest being from the category 'Together'. The majority buying Meat who spent the highest have an income of 60000-100000. The maximum amount spent reaches around 1000 with the majority spending being around 500 for meat products.
#
# 15. The sales of sweet products can also see a possible decrease of 75.59% in the next 2 years. This could also be due to the changes in peoples' dietary plan and routine suggesting they may be looking for a healthier lifestyle.
#
# 16. Wine, while being the most sold product is also one of the most expensive products becoming a luxury item purchased the most by married couples or people who are together. The majority buying wines who spent the highest have an income of 40000-100000. The maximum amount spent goes upwards of 1400 showing that wines have different ranges but become quite a luxury item for being so expensive.
#
# 17. Gold products hasn't been purchased much but will most likely see an increase of 28.24% in the next 2 years. This could be a foreshadowing for the rising demand for gold in the future. Overall, the spending on Gold products is quite low where people prefer to spend 4-5 times more on wine than on gold. This shows the customers don't prefer buying gold as a product here.
#
# 18. The average year of birth of customers is 1968 though the age range is quite broad at 12 years gap from each other.
#
# 19. There is a 72% correlation between the column 'NumCatalogPurchases' and 'MntMeatProducts' implying that customers who make more catalog purchases are likely to spend more on meat products.
#
# 20. There is a 0.64 correlation between column 'MntWines' and 'NumCatalogPurchases', 'NumStorePurchases' implying that customers purchase wine equally from both the stores and catalogues. These 3 variables have a relatively positive linear relationship.
#
# 21. There is a 0.58 correlation between column 'Income' and 'MntWines' implying as the income increases, the purchase of wine will also increase. This also means that the product category 'Wine' can be treated as a luxury item.
#
# 22. We see the same correlation of 0.58 correlation between column 'Income' and 'MntMeatProducts'. This shows that similar to wine, the amount of purchases for meat products increase as the income increases.
#
# 23. There is a 0.59 correlation between column 'Income' and 'NumCatalogPurchases'. This implies as the income increases, the purchase of catalogues will also increase, meaning higher amounts of both meat and wine are purchased through catalogues showing people with higher income purchase catalogues thus further purchasing more expensive products like meat and wine.
#
# 24. A correlation of 0.59 between 'MntFishProducts' and 'MntFruits' indicates a moderately strong positive linear relationship meaning customers who spend more on fish products are likely to also spend more on fruits. This could indicate certain dietary preferences or shopping habits.
#
# 25. We see a negative correlation of -0.55 between 'Income' and 'NumWebVisitsMonth'. This means that they aren't correlated and people from all income groups visit the web for Web Purchases.
#
# 26. We also see a correlation of 0.45 between column 'Kidhome' and 'NumWebVisitsMonth' meaning that a great portion of web visits are from kids.

# %% [markdown]
# ###**Conclusion:**

# %% [markdown]
# 1. The company should increase the discount rate as there is a 100% chance of observing 3122 or more successful purchases out of 5204 total purchases if the probability of success increases to 60% i.e only by 10%. But increasing it too much can also lead to negative results as there was only a 51.65% chance of successful purchases when the probabilty of success increased to 70%.
#
# 2. Increasing the discount rate by 20% can result in a 100% probability of observing 20% more successful purchases through catalogues.
#
# 3. The probability of achieving 100% NO-COMPLAINT rate is 99% for the next 2 years if the company follows this trend.
#
# 4. The company should increase discounts or introduce offers for fishes, fruits and sweet products as they'll see a possible decrease in sales in the next 2 years.
# One possible reason may be unattractive offers and discount rate.
# It could also be due to changes in peoples' dietary plan and routine suggesting they may be looking for a healthier lifestyle.
#
# 5. Meat and Wine products will remain to be the most-sold products for the company if the trend continues..
#
# 6. Gold products will most likely see an increase in the future foreshadowing the rising demand for gold in the future.

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍

# %% [markdown]
# ###**Video Link:**

# %% [markdown]
# https://drive.google.com/file/d/1gftLWpzbWrcY1CGp2EMAaqVS1-oFs1JJ/view?usp=sharing
